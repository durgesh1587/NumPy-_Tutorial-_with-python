# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# this function with randam data ganarate 200 data .
x = np.linspace(1,10 , 200)

# %%
x
# Out:
# array([ 1.        ,  1.04522613,  1.09045226,  1.13567839,  1.18090452,
#         1.22613065,  1.27135678,  1.31658291,  1.36180905,  1.40703518,
#         1.45226131,  1.49748744,  1.54271357,  1.5879397 ,  1.63316583,
#         1.67839196,  1.72361809,  1.76884422,  1.81407035,  1.85929648,
#         1.90452261,  1.94974874,  1.99497487,  2.04020101,  2.08542714,
#         2.13065327,  2.1758794 ,  2.22110553,  2.26633166,  2.31155779,
#         2.35678392,  2.40201005,  2.44723618,  2.49246231,  2.53768844,
#         2.58291457,  2.6281407 ,  2.67336683,  2.71859296,  2.7638191 ,
#         2.80904523,  2.85427136,  2.89949749,  2.94472362,  2.98994975,
#         3.03517588,  3.08040201,  3.12562814,  3.17085427,  3.2160804 ,
#         3.26130653,  3.30653266,  3.35175879,  3.39698492,  3.44221106,
#         3.48743719,  3.53266332,  3.57788945,  3.62311558,  3.66834171,
#         3.71356784,  3.75879397,  3.8040201 ,  3.84924623,  3.89447236,
# ...

# %%
 y = np.sin(x)

# %%
y
# Out:
# array([ 0.84147098,  0.86503801,  0.88683599,  0.90682034,  0.92495019,
#         0.94118847,  0.95550197,  0.96786141,  0.97824152,  0.98662108,
#         0.99298295,  0.99731411,  0.99960571,  0.99985306,  0.99805565,
#         0.99421717,  0.98834546,  0.98045253,  0.97055453,  0.95867168,
#         0.9448283 ,  0.9290527 ,  0.91137713,  0.89183774,  0.8704745 ,
#         0.84733109,  0.82245485,  0.79589664,  0.76771077,  0.7379549 ,
#         0.70668987,  0.67397962,  0.63989104,  0.60449386,  0.56786045,
#         0.53006573,  0.491187  ,  0.45130377,  0.4104976 ,  0.36885193,
#         0.32645195,  0.28338435,  0.23973722,  0.19559981,  0.15106239,
#         0.10621603,  0.06115246,  0.01596383, -0.02925744, -0.07441889,
#        -0.11942814, -0.16419316, -0.20862239, -0.25262498, -0.29611093,
#        -0.33899133, -0.38117846, -0.42258607, -0.46312947, -0.50272574,
#        -0.54129391, -0.5787551 , -0.61503271, -0.65005254, -0.68374298,
# ...

# %%
# this function with large data change in ghrafic data .
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("This is my X data")
plt.xlabel("This is my Y data")
plt.title("This is my title")
plt.show()

# %%
# this Chart data show me no mining this data set .
X = np.random.rand(50)
Y = np.random.rand(50)

# %%
X
# Out:
# array([0.58645159, 0.70755971, 0.37415442, 0.94922321, 0.56365167,
#        0.31436891, 0.46524938, 0.79485849, 0.51281252, 0.76536872,
#        0.74604695, 0.83751136, 0.64556008, 0.55630136, 0.21229149,
#        0.42857639, 0.22465494, 0.7195601 , 0.30015506, 0.95664084,
#        0.45529988, 0.13042879, 0.72200902, 0.00891912, 0.52812162,
#        0.90415686, 0.72912005, 0.77439616, 0.26788794, 0.49256081,
#        0.15748425, 0.60831762, 0.84200268, 0.00357665, 0.61042934,
#        0.45137261, 0.73450602, 0.77423646, 0.21375093, 0.54265265,
#        0.58604329, 0.9681808 , 0.9367254 , 0.66970257, 0.987371  ,
#        0.36285372, 0.37575452, 0.06291877, 0.19786368, 0.65182706])

# %%
Y
# Out:
# array([0.8460638 , 0.39770453, 0.02621104, 0.76136732, 0.25803114,
#        0.1463793 , 0.189446  , 0.13178206, 0.95728104, 0.46406126,
#        0.37091439, 0.59169895, 0.04561585, 0.57505278, 0.89354916,
#        0.91571051, 0.21218943, 0.17831036, 0.52928341, 0.47288514,
#        0.42007001, 0.28689582, 0.03168511, 0.4156024 , 0.86731672,
#        0.76983507, 0.50163749, 0.59662721, 0.01345756, 0.00786379,
#        0.50024006, 0.937179  , 0.54744842, 0.98635208, 0.39351445,
#        0.17402088, 0.76050607, 0.92107268, 0.3256638 , 0.3310137 ,
#        0.47464586, 0.70087931, 0.20872346, 0.98794865, 0.34128054,
#        0.14716324, 0.61529428, 0.47983951, 0.58561965, 0.20492035])

# %%
#this data with "random colour" ,random sizes" difind this code with . 
# this data with small and big size difind * function sizes control.
# alpha control destiti manage colour."dark and light colours. 
colour = np.random.rand(50)
sizes = 100*np.random.rand(50)
plt.scatter(X,Y,c= colour,s=sizes ,alpha=.4)
plt.xlabel("x axis ")
plt.ylabel("y axis ")
plt.title("Random_Data")
# Out:
# Text(0.5, 1.0, 'Random_Data')

# %%
x = ['a','c','v','m','f']

# %%
y = np.random.rand(5)

# %%
x
# Out:
# ['a', 'c', 'v', 'm', 'f']

# %%
y
# Out:
# array([0.68680289, 0.82821868, 0.8603308 , 0.71372427, 0.91991105])

# %%
#this function with bar chart makeing lenth and werth same number .
plt.bar(x,y,)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Bar Chart")
# Out:
# Text(0.5, 1.0, 'Bar Chart')

# %%
#this function with bar chart horizontal makeing lenth and werth same number .
plt.barh(x,y,)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Bar Chart")
# Out:
# Text(0.5, 1.0, 'Bar Chart')

# %%
# figure size control this function with .
plt.figure(figsize=(6,2))
#this '--b' is function create dot dot function line .......
plt.plot(x,y,'--b')
plt.xlabel("This is my X data")
plt.xlabel("This is my Y data")
plt.title("This is my title")
#'greid ' function ganarate col line in butification .
plt.grid()
plt.show()

# %%
colour = np.random.rand(50)
sizes = 100*np.random.rand(50)
# this 'scatter 'function in difind colour 'r' = red short form work this data .
# 2nd sarch google any html any code run like this '#e9967a' 
#this code in 'marker'difind sheps 'x' show all chart .'v' show all chart .
plt.scatter(X,Y,c= '#e9967a',s=sizes ,alpha=.4 ,marker='v')
plt.xlabel("x axis ")
plt.ylabel("y axis ")
plt.title("Random_Data")
# Out:
# Text(0.5, 1.0, 'Random_Data')

# %%
# this chart show plot data index wise data compare.....
x=[1,2,3,4,5,6]
y=[7,5,2,4,5,6]
plt.plot(x,y)
plt.show()

# %%
data =[5,2,4,5,1,2,4,1,2,4,1,34,12,42,1,2,4]

# %%
# this chart 'histogram data chart' this charts mining show orignal data show how many time comes .
plt.hist(data)
plt.xlabel('x axis is show index')
plt.ylabel('y axis is show frequency')
plt.title('histogram data')
plt.show()

# %%
# this chart show plot data index wise data compare
x=[1,2,3,4,5,6]
y=[7,5,2,4,5,6]
#this chart with difind chart colour hepl with "colour code html".
colour =['red','blue','#67f27c','#67f0f2','#ae67f2','#e9967a']
plt.scatter(x,y, c = colour)
plt.show()

# %%
x =np.random.rand(50)
y =np.random.rand(50)
z =np.random.rand(50)

# %%
# this code run '3D' Projection data run 'figure' and 'add_subplot' function with .
fig =plt.figure()
ax = fig.add_subplot(projection ='3d')
ax.scatter(x,y,z)
plt.show()
